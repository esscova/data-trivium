# %% [markdown]
# # Análise de Desempenho Acadêmico

# %% [markdown]
# ## Contexto
#
# ---
#
# Você foi contratado como analista de dados por uma instituição de ensino que oferece cursos em diferentes áreas do conhecimento. A coordenação acadêmica deseja compreender melhor o desempenho dos alunos ao longo do semestre, identificar disciplinas com maiores taxas de aprovação, avaliar a efetividade dos métodos de ensino e detectar alunos que precisam de suporte adicional. Sua missão é utilizar **Pandas** para processar os dados acadêmicos e criar visualizações interativas com **Plotly** que auxiliem a instituição a implementar estratégias de melhoria no processo de ensino-aprendizagem.
#
# ## Objetivos de Aprendizagem
#
# ---
#
# Ao final deste exercício, você será capaz de:
#
# - Explorar e validar dados de desempenho acadêmico
# - Calcular métricas de aproveitamento, média geral e taxa de aprovação
# - Agrupar dados por curso, disciplina e turno
# - Filtrar alunos com base em critérios de performance
# - Criar visualizações que comuniquem o desempenho acadêmico
# - Categorizar alunos por faixa de aproveitamento
#
# ## Competências a Serem Desenvolvidas
#
# ---
#
# - Exploração de dados educacionais com estatísticas descritivas
# - Criação de colunas derivadas para cálculo de média, aproveitamento e situação
# - Agrupamento de dados por curso, disciplina e turno
# - Aplicação de filtros para identificar alunos em situação de risco
# - Categorização de desempenho com `pd.cut()` e manipulação de datas com `pd.to_datetime()`
# - Construção de gráficos interativos com Plotly (dispersão, barras, pizza e barras empilhadas)
#
# ## Dependências e Configurações
#
# ---
#
# Antes de iniciar a análise, importe as bibliotecas necessárias:
# Pandas e Plotly

# %% [markdown]
# ## Conjunto de Dados
#
# ---
#
# Crie um DataFrame com os seguintes dados:
#
# ```python
# {
#     'Matricula': [1001, 1002, 1003, 1004, 1005, 1006, 1007, 1008, 1009, 1010],
#     'Aluno': ['Ana Silva', 'Bruno Costa', 'Carla Souza', 'Daniel Oliveira', 'Elena Santos', 'Felipe Lima', 'Gabriela Rocha', 'Hugo Alves', 'Isabela Martins', 'João Pereira'],
#     'Curso': ['Engenharia', 'Administração', 'Engenharia', 'Ciência da Computação', 'Administração', 'Ciência da Computação', 'Engenharia', 'Administração', 'Ciência da Computação', 'Engenharia'],
#     'Disciplina': ['Cálculo I', 'Contabilidade', 'Física I', 'Algoritmos', 'Marketing', 'Estrutura de Dados', 'Cálculo I', 'Estatística', 'Algoritmos', 'Física I'],
#     'Turno': ['Matutino', 'Noturno', 'Matutino', 'Noturno', 'Noturno', 'Matutino', 'Vespertino', 'Noturno', 'Matutino', 'Vespertino'],
#     'Nota_Prova1': [7.5, 6.0, 5.5, 8.5, 7.0, 9.0, 4.5, 6.5, 8.0, 6.0],
#     'Nota_Prova2': [8.0, 5.5, 6.0, 9.0, 6.5, 8.5, 5.0, 7.0, 8.5, 5.5],
#     'Nota_Trabalho': [9.0, 7.0, 6.5, 9.5, 8.0, 10.0, 6.0, 7.5, 9.0, 7.0],
#     'Frequencia_Percentual': [95, 88, 92, 98, 85, 100, 78, 90, 96, 82],
#     'Data_Matricula': ['2024-02-01', '2024-02-01', '2024-02-05', '2024-02-01', '2024-02-10', '2024-02-01', '2024-02-15', '2024-02-10', '2024-02-01', '2024-02-05']
# }
# ```
#
# **Descrição das Colunas:**
#
# - `Matricula`: Número de matrícula do aluno
# - `Aluno`: Nome completo do aluno
# - `Curso`: Curso no qual o aluno está matriculado
# - `Disciplina`: Nome da disciplina cursada
# - `Turno`: Período de aula (Matutino, Vespertino, Noturno)
# - `Nota_Prova1`: Nota da primeira avaliação (0-10)
# - `Nota_Prova2`: Nota da segunda avaliação (0-10)
# - `Nota_Trabalho`: Nota do trabalho prático (0-10)
# - `Frequencia_Percentual`: Percentual de presença nas aulas
# - `Data_Matricula`: Data de matrícula na disciplina

# %% [markdown]
# ```python
# # Importar bibliotecas
# import pandas as pd
# import plotly.express as px
#
# # Configuração opcional para melhor visualização
# pd.set_option('display.max_columns', None)
# pd.set_option('display.width', None)
# pd.set_option('display.float_format', lambda x: f'{x:.2f}')
# ```

# %% [markdown]
# ## Tarefas
#
# ---
#
# ### 1. Exploração Inicial
#
# - Exibir as cinco primeiras linhas do DataFrame
#     _Dica: Utilize um método que permite visualizar as primeiras entradas de um DataFrame._
#
# - Verificar a existência de valores ausentes
#     _Dica: Explore funções que ajudam a identificar dados nulos em cada coluna._
#
# - Apresentar estatísticas descritivas das colunas `Nota_Prova1`, `Nota_Prova2`, `Nota_Trabalho` e `Frequencia_Percentual`
#     _Dica: Utilize métodos que geram resumos estatísticos para colunas numéricas._
#
# - Visualização: Criar um gráfico de dispersão com Plotly, relacionando `Nota_Prova1` (eixo x) e `Nota_Prova2` (eixo y), com cores diferenciadas por `Curso`
#     _Dica: Considere utilizar uma função de Plotly Express voltada para visualizações de dispersão, que permite identificar a correlação entre as avaliações._
#
#
# ---
#
# ### 2. Cálculos Básicos
#
# - Criar a coluna `Media_Provas`, calculando a média aritmética entre as duas provas ((`Nota_Prova1` + `Nota_Prova2`) / 2)
#     _Dica: Use operações vetoriais para criar colunas derivadas com base em cálculos entre colunas existentes._
#
# - Criar a coluna `Media_Final`, calculando a média ponderada: 30% da Prova 1, 30% da Prova 2 e 40% do Trabalho (`Nota_Prova1` × 0.3 + `Nota_Prova2` × 0.3 + `Nota_Trabalho` × 0.4)
#     _Dica: Realize operações aritméticas com pesos diferentes para cada componente de avaliação._
#
# - Criar a coluna `Situacao`, que contenha "Aprovado" se a `Media_Final` for maior ou igual a 7.0 e a `Frequencia_Percentual` maior ou igual a 75%, caso contrário "Reprovado"
#     _Dica: Utilize estruturas condicionais do Pandas como `np.where()` ou expressões booleanas com `.apply()`._
#
# - Calcular a média geral de todos os alunos na coluna `Media_Final`
#     _Dica: Utilize uma função de agregação que retorna a média dos valores de uma coluna._
#
# - Visualização: Construir um gráfico de barras com Plotly exibindo a `Media_Final` por `Aluno`, com cores diferenciadas por `Situacao`
#     _Dica: Explore a função de Plotly Express que permite criar gráficos de barras simples, facilitando a comparação entre alunos e destacando aprovados/reprovados._
#
#
# ---
#
# ### 3. Análise por Agrupamento
#
# - Agrupar os dados por `Curso` e calcular a média da `Media_Final` e a taxa de aprovação (percentual de alunos aprovados)
#     _Dica: Utilize o método de agrupamento do Pandas e aplique funções estatísticas. Para calcular taxa de aprovação, conte quantos alunos têm "Aprovado" em relação ao total._
#
# - Agrupar os dados por `Disciplina` e calcular a média da `Frequencia_Percentual` e a menor `Media_Final`
#     _Dica: Após agrupar os dados por disciplina, aplique funções de agregação múltiplas como `mean()` e `min()`._
#
# - Agrupar os dados por `Turno` e calcular a média da `Media_Final` em cada turno
#     _Dica: Use o mesmo método de agrupamento, alterando apenas a coluna de agrupamento._
#
# - Visualização: Criar um gráfico de pizza com Plotly mostrando a distribuição de alunos por `Curso`
#     _Dica: Use uma função de Plotly Express específica para gráficos de pizza, ideal para visualizar a composição percentual de alunos por curso._
#
#
# ---
#
# ### 4. Aplicação de Filtros
#
# - Filtrar os alunos com `Media_Final` superior a 8.0
#     _Dica: Utilize expressões condicionais para selecionar linhas com base em valores de uma coluna._
#
# - Filtrar os alunos do turno "Noturno" com `Frequencia_Percentual` inferior a 90%
#     _Dica: Combine múltiplas condições lógicas usando operadores como & (E) para aplicar filtros compostos._
#
# - Filtrar os alunos do curso "Engenharia" que foram reprovados
#     _Dica: Aplique filtros compostos combinando curso e situação acadêmica._
#
# - Visualização: Criar um gráfico de barras com Plotly para os alunos com média superior a 8.0, exibindo `Media_Final` por `Aluno`, com cores por `Turno`
#     _Dica: Considere uma função de Plotly Express que permita destacar categorias por cor em gráficos de barras, facilitando a análise de desempenho por turno._
#
#
# ---
#
# ### 5. Extra (Desafio)
#
# - Converter a coluna `Data_Matricula` para o formato datetime
#     _Dica: Utilize uma função do Pandas que transforma strings em objetos de data, permitindo análises temporais._
#
# - Criar uma nova coluna `Conceito` que classifique os alunos como "Excelente" (média ≥ 9.0), "Bom" (7.0 ≤ média < 9.0), "Regular" (5.0 ≤ média < 7.0) ou "Insuficiente" (média < 5.0)
#     _Dica: Explore funções que permitem segmentar valores numéricos em faixas categóricas, úteis para classificar desempenho acadêmico._
#
# - Identificar qual disciplina teve a maior média final entre os alunos e exibir o resultado
#     _Dica: Agrupe os dados por disciplina, calcule a média e utilize funções de ordenação para encontrar o maior valor._
#
# - Criar uma coluna `Aproveitamento_Percentual` que represente a `Media_Final` como percentual (multiplicando por 10)
#     _Dica: Utilize operações aritméticas simples para transformar a escala de notas._
#
# - Visualização: Criar um gráfico de barras empilhadas com Plotly mostrando a contagem de alunos por `Conceito` em cada `Curso`
#     _Dica: Utilize uma função de Plotly Express que permita empilhar categorias dentro de grupos em gráficos de barras, revelando a distribuição de conceitos por curso._
#
#
# ---
#
# ## Reflexão e Perguntas Adicionais
#
# ---
#
# Após concluir as tarefas, reflita sobre os seguintes pontos:
#
# 1. **Padrões Identificados**: Quais cursos e turnos apresentaram melhor desempenho acadêmico? Existe correlação entre frequência e média final? Como as notas das provas se relacionam com a nota do trabalho?
#
# 2. **Qualidade dos Dados**: Os dados estavam completos e consistentes? Como você lidaria com alunos que desistiram da disciplina ou que têm avaliações pendentes?
#
# 3. **Insights para o Negócio**: Com base na sua análise, quais recomendações você daria para a instituição sobre metodologias de ensino, horários de aula e programas de monitoria?
#
# 4. **Próximos Passos**: Que outras análises você poderia realizar com esses dados? Pense em análises de evolução temporal do desempenho, comparação entre disciplinas similares ou identificação de alunos em risco de evasão.
#
# 5. **Visualizações**: As visualizações criadas comunicam claramente o desempenho acadêmico? Qual visualização foi mais efetiva para identificar áreas que precisam de intervenção pedagógica?
#
#
# ---
#
# ## Recursos Adicionais
#
# ---
#
# Para aprofundar seus conhecimentos:
#
# - **Documentação do Pandas**: https://pandas.pydata.org/docs/
# - **Documentação do Plotly**: https://plotly.com/python/
# - **Tutoriais de Análise de Dados**: Explore cursos online e notebooks no Kaggle
# - **Análise Educacional com Python**: Busque materiais específicos sobre learning analytics e educação baseada em dados
